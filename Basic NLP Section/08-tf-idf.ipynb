# %% [markdown]
# # TF-IDF
#
# TF-IDF stands for:
#
# Term Frequency – Inverse Document Frequency
#
# It improves Bag of Words by reducing the importance of very common words and increasing the importance of rare words.

# %% [markdown]
# ## Import Library

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Example Dataset

# %%
documents = [
    "I love natural language processing",
    "I love machine learning",
    "Machine learning is part of artificial intelligence", 
    "Natural language processing is interesting"
]

# %% [markdown]
# ## Initialize TF-IDF Vectorizer

# %%
vectorizer = TfidfVectorizer()

# %% [markdown]
# ## Fit and Transform

# %%
X = vectorizer.fit_transform(documents)

# %% [markdown]
# ## Convert to DataFrame

# %%
import pandas as pd

tfidf_df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

tfidf_df
# Out:
#    artificial  intelligence  interesting        is  language  learning  \
# 0    0.000000      0.000000     0.000000  0.000000  0.500000  0.000000
# 1    0.000000      0.000000     0.000000  0.000000  0.000000  0.577350
# 2    0.412928      0.412928     0.000000  0.325557  0.000000  0.325557
# 3    0.000000      0.000000     0.535566  0.422247  0.422247  0.000000
#
#       love   machine   natural        of      part  processing
# 0  0.50000  0.000000  0.500000  0.000000  0.000000    0.500000
# 1  0.57735  0.577350  0.000000  0.000000  0.000000    0.000000
# 2  0.00000  0.325557  0.000000  0.412928  0.412928    0.000000
# 3  0.00000  0.000000  0.422247  0.000000  0.000000    0.422247

# %% [markdown]
# ## Advantages of TF-IDF
#
# - Reduces importance of common words
# - Highlights informative words
# - Improves many traditional NLP models
